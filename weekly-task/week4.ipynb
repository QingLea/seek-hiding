# %% [markdown]
# ---

# %% [markdown]
# # IT00CJ42: Search and Optimization Algorithms

# %% [markdown]
# **Restart the kernel and run all cells** before you turn this problem in, make sure everything runs as expected.
#
# Make sure you fill in any place that says `YOUR CODE HERE`.

# %% [markdown]
# ---

# %% [markdown]
# ## Week 4
#
# Solve QAP with tabu search

# %% [markdown]
# ### Imports and setting seed

# %%
import math
import numpy as np
import random

# %% [markdown]
# ### Solution check
# We use the function **check** to implement tests for your solution

# %%
def check(expression, message=""):
    if not expression:
        raise AssertionError(message)
    print(message+" : passed.")

# %% [markdown]
# ## Task 1: Implement neighbors and best_neighbor_swap

# %%
class Solution:
    def __init__(self, permutation, flows, distances):
        assert flows.shape == distances.shape, "Flow and distance matrices have to be of the same shape."
        self.permutation = np.array(permutation)
        self.flows = flows
        self.distances = distances
        self.optimal = None

    def __str__(self):
        return str(self.permutation)
    def __repr__(self):
        return str(self.permutation)

    # Load a dat file with a problem instance
    @classmethod
    def from_file(cls,  filename):
        # load in all rows into lists
        dat = [i.strip().split() for i in open(filename).readlines()]
        # remove empty lists
        res = [ele for ele in dat if ele != []]
        # convert strings to integers
        temp = [list(map(int, x)) for x in res]

        # first row: size, optimal value
        info = temp[0]
        size = info[0]
        optimal = info[1]

        # size*rows down is the distance
        distances = np.array(temp[1:size + 1]).reshape(size, size)
        # size*rows after that is the flow
        flows = np.array(temp[size + 1:len(temp)]).reshape(size, size)
        permutation= np.random.permutation(distances.shape[0])
        sol=cls(permutation,flows,distances)
        sol.optimal=optimal
        return sol

    @property
    def objective(self):
          return self.evaluate_objective(self.permutation, self.flows, self.distances)

    @classmethod
    def evaluate_objective(cls, permutation, flows, distances):
        # When doing a swap the objective can be updated with less cost, but we
        # do not care.
        objective = 0.0
        for i in range(flows.shape[0]):
            for j in range(i + 1, flows.shape[1]):
                 objective += flows[i, j] * distances[permutation[i], permutation[j]]

        # The matrices are symmetric.
        return 2*objective
        
    def neighbors(self, tabu=None, threshold=0):
        # TODO: Implement this. The returned value should be a list of tuples
        # (i,j) representing non-tabu swaps.
        neighborhood = []
        for i in range(len(self.permutation)):
            for j in range(i + 1, len(self.permutation)):
                if tabu is None or (i, j) not in tabu:
                    neighborhood.append((i, j))
        return neighborhood
        
    def best_neighbor_swap(self, tabu=None, threshold=0):
        # TODO: Implement this. The result should be the swap (i,j), when
        # applied to self, yields the best objective value. If no such (i,j)
        # exists, None should be returned.
        best_swap = None
        best_objective = float('inf') 
        for i in range(len(self.permutation)):
            for j in range(i + 1, len(self.permutation)):
                if tabu is None or (i, j) not in tabu:
                    new_permutation = self.permutation.copy()
                    new_permutation[i], new_permutation[j] = new_permutation[j], new_permutation[i]
                    new_objective = self.evaluate_objective(new_permutation, self.flows, self.distances)
                # search for a swap
                    if new_objective < best_objective:
                        best_objective = new_objective
                        best_swap = (i, j)
        
        return best_swap
        
    def swap(self, i, j):
        tmp = self.permutation[i]
        P = self.permutation.copy()
        P[i] = self.permutation[j]
        P[j] = tmp
        return Solution(P, self.flows, self.distances)

# %% [markdown]
# ## Task 2: Implement Tabu Search

# %%
def tabu_search(initial_solution, tenure=10,budget=100):
    tabu = []
    X = initial_solution
    best_solution = initial_solution
    for iteration in range(1, budget + 1):
        print("Iteration {}".format(iteration))
        print("Current solution {}.".format(X))
        current_objective = X.objective
        best_swap = X.best_neighbor_swap(tabu, iteration)
        if best_swap is None: break
        X = X.swap(*best_swap)
        print("Best swap {} with objective {}. Difference to current {}.".format(best_swap, X.objective, X.objective - current_objective))
        if X.objective < best_solution.objective:
            best_solution = X
        print("Current best solution {} with objective {}.".format(best_solution, best_solution.objective))
        print("Tabu list state:")
        print(tabu)
        print()
    print("Best solution {} with objective {}.".format(best_solution, best_solution.objective))
    return best_solution

# %% [markdown]
# ## Check solution for NUG5

# %%
nug5 = Solution.from_file("../res/data/nug5.dat")

# %%
# set an arbitrary permutation
sol = nug5
sol.permutation = np.array([2,4,1,5,3]) - 1

# %%
check(len(sol.neighbors())==10,"There are 10 neighbors")
check(sol.best_neighbor_swap()==(2,3),"(2,3) is the best initial swap")
# Out:
# There are 10 neighbors : passed.
# (2,3) is the best initial swap : passed.

# %%
# Allow for a 10% deviation from optimal
acceptable_objective = nug5.optimal * 1.10
tenure = 5
budget = 500
np.random.seed(1)
random.seed(1)
sol = tabu_search(nug5, tenure=tenure, budget=budget)
# Out:
# Iteration 1
# Current solution [1 3 0 4 2].
# Best swap (2, 3) with objective 50.0. Difference to current -20.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 2
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 3
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 4
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 5
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 6
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 7
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 8
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 9
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 10
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 11
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 12
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 13
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 14
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 15
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 16
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 17
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 18
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 19
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 20
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 21
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 22
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 23
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 24
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 25
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 26
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 27
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 28
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 29
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 30
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 31
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 32
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 33
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 34
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 35
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 36
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 37
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 38
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 39
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 40
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 41
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 42
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 43
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 44
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 45
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 46
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 47
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 48
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 49
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 50
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 51
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 52
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 53
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 54
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 55
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 56
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 57
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 58
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 59
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 60
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 61
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 62
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 63
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 64
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 65
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 66
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 67
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 68
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 69
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 70
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 71
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 72
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 73
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 74
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 75
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 76
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 77
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 78
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 79
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 80
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 81
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 82
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 83
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 84
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 85
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 86
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 87
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 88
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 89
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 90
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 91
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 92
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 93
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 94
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 95
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 96
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 97
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 98
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 99
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 100
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 101
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 102
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 103
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 104
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 105
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 106
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 107
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 108
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 109
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 110
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 111
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 112
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 113
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 114
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 115
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 116
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 117
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 118
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 119
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 120
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 121
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 122
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 123
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 124
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 125
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 126
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 127
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 128
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 129
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 130
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 131
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 132
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 133
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 134
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 135
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 136
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 137
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 138
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 139
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 140
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 141
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 142
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 143
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 144
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 145
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 146
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 147
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 148
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 149
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 150
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 151
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 152
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 153
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 154
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 155
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 156
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 157
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 158
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 159
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 160
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 161
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 162
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 163
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 164
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 165
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 166
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 167
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 168
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 169
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 170
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 171
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 172
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 173
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 174
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 175
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 176
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 177
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 178
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 179
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 180
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 181
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 182
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 183
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 184
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 185
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 186
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 187
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 188
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 189
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 190
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 191
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 192
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 193
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 194
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 195
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 196
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 197
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 198
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 199
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 200
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 201
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 202
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 203
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 204
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 205
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 206
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 207
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 208
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 209
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 210
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 211
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 212
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 213
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 214
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 215
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 216
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 217
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 218
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 219
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 220
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 221
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 222
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 223
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 224
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 225
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 226
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 227
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 228
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 229
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 230
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 231
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 232
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 233
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 234
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 235
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 236
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 237
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 238
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 239
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 240
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 241
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 242
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 243
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 244
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 245
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 246
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 247
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 248
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 249
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 250
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 251
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 252
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 253
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 254
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 255
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 256
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 257
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 258
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 259
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 260
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# ...
# Tabu list state:
# []
#
# Iteration 415
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 416
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 417
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 418
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 419
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 420
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 421
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 422
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 423
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 424
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 425
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 426
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 427
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 428
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 429
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 430
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 431
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 432
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 433
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 434
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 435
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 436
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 437
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 438
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 439
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 440
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 441
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 442
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 443
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 444
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 445
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 446
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 447
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 448
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 449
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 450
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 451
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 452
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 453
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 454
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 455
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 456
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 457
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 458
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 459
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 460
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 461
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 462
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 463
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 464
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 465
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 466
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 467
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 468
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 469
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 470
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 471
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 472
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 473
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 474
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 475
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 476
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 477
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 478
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 479
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 480
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 481
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 482
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 483
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 484
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 485
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 486
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 487
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 488
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 489
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 490
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 491
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 492
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 493
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 494
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 495
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 496
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 497
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 498
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 499
# Current solution [2 3 4 0 1].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Iteration 500
# Current solution [1 3 4 0 2].
# Best swap (0, 4) with objective 50.0. Difference to current 0.0.
# Current best solution [1 3 4 0 2] with objective 50.0.
# Tabu list state:
# []
#
# Best solution [1 3 4 0 2] with objective 50.0.

# %%
check(sol.objective<=nug5.optimal*1.10,f"Best objective should be within 10% of optimal {nug5.optimal}")
# Out:
# Best objective should be within 10% of optimal 50 : passed.

# %% [markdown]
# ## Check solution for NUG20

# %%
nug20 = Solution.from_file("../res/data/nug20.dat")
# Set the tenure and budget for the search

tenure = int(0.20 * 20)
budget = 100
np.random.seed(1)
random.seed(1)
sol = tabu_search(nug20, tenure=tenure, budget=budget)
# Out:
# Iteration 1
# Current solution [ 3 16  6 10  2 14  4 17  7  1 13  0 19 18  9 15  8 12 11  5].
# Best swap (9, 11) with objective 3100.0. Difference to current -184.0.
# Current best solution [ 3 16  6 10  2 14  4 17  7  0 13  1 19 18  9 15  8 12 11  5] with objective 3100.0.
# Tabu list state:
# []
#
# Iteration 2
# Current solution [ 3 16  6 10  2 14  4 17  7  0 13  1 19 18  9 15  8 12 11  5].
# Best swap (5, 7) with objective 2976.0. Difference to current -124.0.
# Current best solution [ 3 16  6 10  2 17  4 14  7  0 13  1 19 18  9 15  8 12 11  5] with objective 2976.0.
# Tabu list state:
# []
#
# Iteration 3
# Current solution [ 3 16  6 10  2 17  4 14  7  0 13  1 19 18  9 15  8 12 11  5].
# Best swap (6, 18) with objective 2876.0. Difference to current -100.0.
# Current best solution [ 3 16  6 10  2 17 11 14  7  0 13  1 19 18  9 15  8 12  4  5] with objective 2876.0.
# Tabu list state:
# []
#
# Iteration 4
# Current solution [ 3 16  6 10  2 17 11 14  7  0 13  1 19 18  9 15  8 12  4  5].
# Best swap (3, 5) with objective 2792.0. Difference to current -84.0.
# Current best solution [ 3 16  6 17  2 10 11 14  7  0 13  1 19 18  9 15  8 12  4  5] with objective 2792.0.
# Tabu list state:
# []
#
# Iteration 5
# Current solution [ 3 16  6 17  2 10 11 14  7  0 13  1 19 18  9 15  8 12  4  5].
# Best swap (1, 3) with objective 2752.0. Difference to current -40.0.
# Current best solution [ 3 17  6 16  2 10 11 14  7  0 13  1 19 18  9 15  8 12  4  5] with objective 2752.0.
# Tabu list state:
# []
#
# Iteration 6
# Current solution [ 3 17  6 16  2 10 11 14  7  0 13  1 19 18  9 15  8 12  4  5].
# Best swap (2, 8) with objective 2728.0. Difference to current -24.0.
# Current best solution [ 3 17  7 16  2 10 11 14  6  0 13  1 19 18  9 15  8 12  4  5] with objective 2728.0.
# Tabu list state:
# []
#
# Iteration 7
# Current solution [ 3 17  7 16  2 10 11 14  6  0 13  1 19 18  9 15  8 12  4  5].
# Best swap (7, 12) with objective 2706.0. Difference to current -22.0.
# Current best solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2706.0.
# Tabu list state:
# []
#
# Iteration 8
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 9
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 10
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 11
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 12
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 13
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 14
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 15
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 16
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 17
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 18
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 19
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 20
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 21
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 22
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 23
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 24
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 25
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 26
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 27
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 28
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 29
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 30
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 31
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 32
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 33
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 34
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 35
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 36
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 37
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 38
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 39
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 40
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 41
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 42
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 43
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 44
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 45
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 46
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 47
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 48
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 49
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 50
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 51
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 52
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 53
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 54
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 55
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 56
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 57
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 58
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 59
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 60
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 61
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 62
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 63
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 64
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 65
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 66
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 67
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 68
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 69
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 70
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 71
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 72
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 73
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 74
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 75
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 76
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 77
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 78
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 79
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 80
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 81
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 82
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 83
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 84
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 85
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 86
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 87
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 88
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 89
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 90
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 91
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 92
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 93
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 94
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 95
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 96
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 97
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 98
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 99
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 100
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.

# %%
# Allow for a 10% deviation from optimal
check(sol.objective<=nug20.optimal*1.10,f"Best objective should be within 10% of optimal {nug20.optimal}")
# Out:
# Best objective should be within 10% of optimal 2570 : passed.

# %%
# Set the tenure, budget and the number of replicas for the search
replicas = 10

# %%
for i in range(replicas):
    np.random.seed(i)
    random.seed(i)
    nug20 = Solution.from_file("../res/data/nug20.dat")
    sol = tabu_search(nug20, tenure=tenure, budget=budget)
    # Allow for a 10% deviation from optimal
    check(sol.objective<=nug20.optimal*1.10,f"Best objective should be within 10% of optimal {nug20.optimal}")
# Out:
# Iteration 1
# Current solution [18  1 19  8 10 17  6 13  4  2  5 14  9  7 16 11  3  0 15 12].
# Best swap (4, 10) with objective 3144.0. Difference to current -256.0.
# Current best solution [18  1 19  8  5 17  6 13  4  2 10 14  9  7 16 11  3  0 15 12] with objective 3144.0.
# Tabu list state:
# []
#
# Iteration 2
# Current solution [18  1 19  8  5 17  6 13  4  2 10 14  9  7 16 11  3  0 15 12].
# Best swap (2, 12) with objective 3052.0. Difference to current -92.0.
# Current best solution [18  1  9  8  5 17  6 13  4  2 10 14 19  7 16 11  3  0 15 12] with objective 3052.0.
# Tabu list state:
# []
#
# Iteration 3
# Current solution [18  1  9  8  5 17  6 13  4  2 10 14 19  7 16 11  3  0 15 12].
# Best swap (6, 16) with objective 2980.0. Difference to current -72.0.
# Current best solution [18  1  9  8  5 17  3 13  4  2 10 14 19  7 16 11  6  0 15 12] with objective 2980.0.
# Tabu list state:
# []
#
# Iteration 4
# Current solution [18  1  9  8  5 17  3 13  4  2 10 14 19  7 16 11  6  0 15 12].
# Best swap (15, 18) with objective 2910.0. Difference to current -70.0.
# Current best solution [18  1  9  8  5 17  3 13  4  2 10 14 19  7 16 15  6  0 11 12] with objective 2910.0.
# Tabu list state:
# []
#
# Iteration 5
# Current solution [18  1  9  8  5 17  3 13  4  2 10 14 19  7 16 15  6  0 11 12].
# Best swap (17, 18) with objective 2862.0. Difference to current -48.0.
# Current best solution [18  1  9  8  5 17  3 13  4  2 10 14 19  7 16 15  6 11  0 12] with objective 2862.0.
# Tabu list state:
# []
#
# Iteration 6
# Current solution [18  1  9  8  5 17  3 13  4  2 10 14 19  7 16 15  6 11  0 12].
# Best swap (3, 14) with objective 2820.0. Difference to current -42.0.
# Current best solution [18  1  9 16  5 17  3 13  4  2 10 14 19  7  8 15  6 11  0 12] with objective 2820.0.
# Tabu list state:
# []
#
# Iteration 7
# Current solution [18  1  9 16  5 17  3 13  4  2 10 14 19  7  8 15  6 11  0 12].
# Best swap (0, 6) with objective 2788.0. Difference to current -32.0.
# Current best solution [ 3  1  9 16  5 17 18 13  4  2 10 14 19  7  8 15  6 11  0 12] with objective 2788.0.
# Tabu list state:
# []
#
# Iteration 8
# Current solution [ 3  1  9 16  5 17 18 13  4  2 10 14 19  7  8 15  6 11  0 12].
# Best swap (1, 6) with objective 2750.0. Difference to current -38.0.
# Current best solution [ 3 18  9 16  5 17  1 13  4  2 10 14 19  7  8 15  6 11  0 12] with objective 2750.0.
# Tabu list state:
# []
#
# Iteration 9
# Current solution [ 3 18  9 16  5 17  1 13  4  2 10 14 19  7  8 15  6 11  0 12].
# Best swap (0, 5) with objective 2720.0. Difference to current -30.0.
# Current best solution [17 18  9 16  5  3  1 13  4  2 10 14 19  7  8 15  6 11  0 12] with objective 2720.0.
# Tabu list state:
# []
#
# Iteration 10
# Current solution [17 18  9 16  5  3  1 13  4  2 10 14 19  7  8 15  6 11  0 12].
# Best swap (14, 19) with objective 2692.0. Difference to current -28.0.
# Current best solution [17 18  9 16  5  3  1 13  4  2 10 14 19  7 12 15  6 11  0  8] with objective 2692.0.
# Tabu list state:
# []
#
# Iteration 11
# Current solution [17 18  9 16  5  3  1 13  4  2 10 14 19  7 12 15  6 11  0  8].
# Best swap (7, 16) with objective 2658.0. Difference to current -34.0.
# Current best solution [17 18  9 16  5  3  1  6  4  2 10 14 19  7 12 15 13 11  0  8] with objective 2658.0.
# Tabu list state:
# []
#
# Iteration 12
# Current solution [17 18  9 16  5  3  1  6  4  2 10 14 19  7 12 15 13 11  0  8].
# Best swap (4, 9) with objective 2640.0. Difference to current -18.0.
# Current best solution [17 18  9 16  2  3  1  6  4  5 10 14 19  7 12 15 13 11  0  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 13
# Current solution [17 18  9 16  2  3  1  6  4  5 10 14 19  7 12 15 13 11  0  8].
# Best swap (7, 13) with objective 2628.0. Difference to current -12.0.
# Current best solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8] with objective 2628.0.
# Tabu list state:
# []
#
# Iteration 14
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 15
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 16
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 17
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 18
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 19
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 20
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 21
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 22
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 23
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 24
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 25
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 26
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 27
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 28
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 29
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 30
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 31
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 32
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 33
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 34
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 35
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 36
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 37
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 38
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 39
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 40
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 41
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 42
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 43
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 44
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 45
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 46
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 47
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 48
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 49
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 50
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 51
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 52
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 53
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 54
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 55
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 56
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 57
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 58
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 59
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 60
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 61
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 62
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 63
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 64
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 65
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 66
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 67
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 68
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 69
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 70
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 71
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 72
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 73
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 74
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 75
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 76
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 77
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 78
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 79
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 80
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 81
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 82
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 83
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 84
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 85
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 86
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 87
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 88
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 89
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 90
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 91
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 92
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 93
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 94
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 95
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 96
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 97
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 98
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 99
# Current solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2628.0. Difference to current 2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Iteration 100
# Current solution [17 18  9 16  2  3  1  7  4  5 10 14 19  6 12 15 13 11  0  8].
# Best swap (7, 12) with objective 2626.0. Difference to current -2.0.
# Current best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Tabu list state:
# []
#
# Best solution [17 18  9 16  2  3  1 19  4  5 10 14  7  6 12 15 13 11  0  8] with objective 2626.0.
# Best objective should be within 10% of optimal 2570 : passed.
# Iteration 1
# Current solution [ 3 16  6 10  2 14  4 17  7  1 13  0 19 18  9 15  8 12 11  5].
# Best swap (9, 11) with objective 3100.0. Difference to current -184.0.
# Current best solution [ 3 16  6 10  2 14  4 17  7  0 13  1 19 18  9 15  8 12 11  5] with objective 3100.0.
# Tabu list state:
# []
#
# Iteration 2
# Current solution [ 3 16  6 10  2 14  4 17  7  0 13  1 19 18  9 15  8 12 11  5].
# Best swap (5, 7) with objective 2976.0. Difference to current -124.0.
# Current best solution [ 3 16  6 10  2 17  4 14  7  0 13  1 19 18  9 15  8 12 11  5] with objective 2976.0.
# Tabu list state:
# []
#
# Iteration 3
# Current solution [ 3 16  6 10  2 17  4 14  7  0 13  1 19 18  9 15  8 12 11  5].
# Best swap (6, 18) with objective 2876.0. Difference to current -100.0.
# Current best solution [ 3 16  6 10  2 17 11 14  7  0 13  1 19 18  9 15  8 12  4  5] with objective 2876.0.
# Tabu list state:
# []
#
# Iteration 4
# Current solution [ 3 16  6 10  2 17 11 14  7  0 13  1 19 18  9 15  8 12  4  5].
# Best swap (3, 5) with objective 2792.0. Difference to current -84.0.
# Current best solution [ 3 16  6 17  2 10 11 14  7  0 13  1 19 18  9 15  8 12  4  5] with objective 2792.0.
# Tabu list state:
# []
#
# Iteration 5
# Current solution [ 3 16  6 17  2 10 11 14  7  0 13  1 19 18  9 15  8 12  4  5].
# Best swap (1, 3) with objective 2752.0. Difference to current -40.0.
# Current best solution [ 3 17  6 16  2 10 11 14  7  0 13  1 19 18  9 15  8 12  4  5] with objective 2752.0.
# Tabu list state:
# []
#
# Iteration 6
# Current solution [ 3 17  6 16  2 10 11 14  7  0 13  1 19 18  9 15  8 12  4  5].
# Best swap (2, 8) with objective 2728.0. Difference to current -24.0.
# Current best solution [ 3 17  7 16  2 10 11 14  6  0 13  1 19 18  9 15  8 12  4  5] with objective 2728.0.
# Tabu list state:
# []
#
# Iteration 7
# Current solution [ 3 17  7 16  2 10 11 14  6  0 13  1 19 18  9 15  8 12  4  5].
# Best swap (7, 12) with objective 2706.0. Difference to current -22.0.
# Current best solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2706.0.
# Tabu list state:
# []
#
# Iteration 8
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 9
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 10
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 11
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 12
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 13
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 14
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 15
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 16
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 17
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 18
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 19
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 20
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 21
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 22
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 23
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 24
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 25
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 26
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 27
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 28
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 29
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 30
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 31
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 32
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 33
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 34
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 35
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 36
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 37
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 38
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 39
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 40
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 41
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 42
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 43
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 44
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 45
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 46
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 47
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 48
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 49
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 50
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 51
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 52
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 53
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 54
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 55
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 56
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 57
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 58
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 59
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 60
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 61
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 62
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 63
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 64
# Current solution [ 3 17  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2696.0. Difference to current -10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 65
# Current solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5].
# Best swap (0, 1) with objective 2706.0. Difference to current 10.0.
# Current best solution [17  3  7 16  2 10 11 19  6  0 13  1 14 18  9 15  8 12  4  5] with objective 2696.0.
# Tabu list state:
# []
#
# Iteration 66
# ...
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 47
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 48
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 49
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 50
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 51
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 52
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 53
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 54
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 55
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 56
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 57
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 58
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 59
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 60
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 61
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 62
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 63
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 64
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 65
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 66
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 67
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 68
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 69
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 70
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 71
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 72
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 73
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 74
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 75
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 76
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 77
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 78
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 79
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 80
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 81
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 82
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 83
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 84
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 85
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 86
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 87
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 88
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 89
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 90
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 91
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 92
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 93
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 94
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 95
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 96
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 97
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 98
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 99
# Current solution [ 3 10  6  0 16 18 19  7  4 12  1 14 11  9  5 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Iteration 100
# Current solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8].
# Best swap (9, 14) with objective 2640.0. Difference to current 0.0.
# Current best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Tabu list state:
# []
#
# Best solution [ 3 10  6  0 16 18 19  7  4  5  1 14 11  9 12 15 13 17  2  8] with objective 2640.0.
# Best objective should be within 10% of optimal 2570 : passed.
